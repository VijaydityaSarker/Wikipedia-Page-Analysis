# %% [markdown]
# <FONT size=24>
# VIJAYDITYA SARKER<br>
# REG.NO-22200046<br>
# BIGDATA ASSIGNMENT-1
# <FONT/>

# %% [markdown]
# Here i am mounting my google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !yes y | unminimize
# Out:
# This system has been minimized by removing packages and content that are
# not required on a system that users do not log into.
#
# This script restores content and packages that are found on a default
# Ubuntu server system in order to make this system more suitable for
# interactive use.
#
# Reinstallation of packages may fail due to changes to the system
# configuration, the presence of third-party packages, or for other
# reasons.
#
# This operation may take some time.

# %% [markdown]
# Man or manual is used to display the user manual of any command that we can run on the terminal

# %%
! man echo
# Out:
# ECHO(1POSIX)               POSIX Programmer's Manual              ECHO(1POSIX)
#
# G
#        This  manual  page is part of the POSIX Programmer's Manual.  The Linux
#        implementation of this interface may differ (consult the  corresponding
#        Linux  manual page for details of Linux behavior), or the interface may
#        not be implemented on Linux.
#
# E
#        echo — write arguments to standard output
#
# S
# ]
#
# N
# o utility writes its arguments to standard output, followed by a
#        <newline>.  If there are no arguments, only the <newline> is written.
#
# S
# " argument in the manner
#        specified  by  Guideline  10  of  the  Base   Definitions   volume   of
# " shall be
#        recognized as a string operand.
#
#        Implementations shall not support any options.
#
# S
#        The following operands shall be supported:
#
# g    A string to be written to standard output. If the first oper‐
# n,  or if any of the operands contain a <backslash>
# ...

# %% [markdown]
# printing a welcome text

# %%
# !echo hello world , first hour of project
# Out:
# hello world , first hour of project

# %% [markdown]
# checking if i am using bash shell

# %%
# !echo  $SHELL
# Out:
# /bin/bash

# %% [markdown]
# checking my directory

# %%
! pwd
# Out:
# /content

# %% [markdown]
# LISTING OUT MY DIRECTORY

# %%
! ls
# Out:
# drive  sample_data

# %%
# %cd /content
# Out:
# /content

# %%
# !ls
# Out:
# drive  sample_data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# CREATION OF directory "wikipedia-ml-raw"  and also the test.

# %%
# %%bash
#
# folder_name="wikipedia-ml-raw"
#
# if [ ! -d "wikipedia-ml-raw" ]; then
#     mkdir "wikipedia-ml-raw"
#     echo "Folder 'wikipedia-ml-raw' created."
# else
#     echo "Folder 'wikipedia-ml-raw' already exists."
# fi
# Out:
# Folder 'wikipedia-ml-raw' created.

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# **NoTE- This is where my files given are stored-article-ids.txt   parse_article.sh and parse_article.py**

# %%
# %cd /content/drive/MyDrive/Big_data_assignment_files
# Out:
# /content/drive/MyDrive/Big_data_assignment_files

# %%
# !ls
# Out:
# article-ids.txt   parse_article.sh  wikipedia-ml-raw
# parse_article.py  wikipedia-ml

# %% [markdown]
# **Copying files from my drive to the directory**

# %%
# !cp parse_article.py parse_article.sh /content

# %%
# !cp article-ids.txt /content/wikipedia-ml-raw

# %%
# %cd /content
# Out:
# /content

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# **We can see that i have moved the given files to my directory**

# %%
# !ls
# Out:
# drive  parse_article.py  parse_article.sh  sample_data	wikipedia-ml-raw

# %%
# %cd /content/wikipedia-ml-raw
# Out:
# /content/wikipedia-ml-raw

# %%
# !ls
# Out:
# article-ids.txt

# %% [markdown]
# checking the contents of the text file

# %%
! cat article-ids.txt
# Out:
# 530966344
# 561799120
# 589188932
# 611596476
# 640893447
# 669305018
# 697788566
# 727649049
# 757727579
# 788095566
# 818847631
# 848001726
# 876474031
# 903232737
# 934837523
# 965344897
# 999142720
# 1029354622
# 1063409105
# 1095436080
# 1130883349

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# using mapfile as it is used to read array

# %%
# %%bash
# mapfile -t MYID < article-ids.txt
#
# #echo ${MYID[@]}
# for number in "${MYID[@]}"; do
#   echo "$number"
# done
# Out:
# 530966344
# 561799120
# 589188932
# 611596476
# 640893447
# 669305018
# 697788566
# 727649049
# 757727579
# 788095566
# 818847631
# 848001726
# 876474031
# 903232737
# 934837523
# 965344897
# 999142720
# 1029354622
# 1063409105
# 1095436080
# 1130883349

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Retriving all the files using articles-id

# %%
# %%bash
#
# while read number; do
#     filename="machine_learning_${number}.html"
#     url="https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=${number}"
#     wget -O "$filename" "$url"
# done < /content/wikipedia-ml-raw/article-ids.txt
# Out:
# --2023-03-20 15:03:23--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=530966344
# Resolving en.wikipedia.org (en.wikipedia.org)... 103.102.166.224, 2620:0:861:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|103.102.166.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘machine_learning_530966344.html’
#
#      0K .......... .......... .......... .......... ..........  121K
#     50K .......... .......... .......... .......... ..........  302K
#    100K .......... .......... .....                             696K=0.6s
#
# 2023-03-20 15:03:25 (204 KB/s) - ‘machine_learning_530966344.html’ saved [128440]
#
# --2023-03-20 15:03:25--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=561799120
# Resolving en.wikipedia.org (en.wikipedia.org)... 103.102.166.224, 2620:0:861:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|103.102.166.224|:443... connected.
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# going to the wikipedia-ml raw folder

# %%
# %cd /content/wikipedia-ml-raw
# Out:
# /content/wikipedia-ml-raw

# %%
# !ls
# Out:
# article-ids.txt			  machine_learning_727649049.html
# machine_learning_1029354622.html  machine_learning_757727579.html
# machine_learning_1063409105.html  machine_learning_788095566.html
# machine_learning_1095436080.html  machine_learning_818847631.html
# machine_learning_1130883349.html  machine_learning_848001726.html
# machine_learning_530966344.html   machine_learning_876474031.html
# machine_learning_561799120.html   machine_learning_903232737.html
# machine_learning_589188932.html   machine_learning_934837523.html
# machine_learning_611596476.html   machine_learning_965344897.html
# machine_learning_640893447.html   machine_learning_999142720.html
# machine_learning_669305018.html   machine_learning_.html
# machine_learning_697788566.html

# %%
# %cd /content
# Out:
# /content

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !bash parse_article.sh
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# %cd /content/wikipedia-ml
# Out:
# /content/wikipedia-ml

# %% [markdown]
# We can see that files are in correct order

# %%
# !ls
# Out:
# 'article_Machine learning - Wikipedia_2013_1_2.txt'
# 'article_Machine learning - Wikipedia_2013_6_27.txt'
# 'article_Machine learning - Wikipedia_2014_1_4.txt'
# 'article_Machine learning - Wikipedia_2014_6_4.txt'
# 'article_Machine learning - Wikipedia_2015_1_4.txt'
# 'article_Machine learning - Wikipedia_2015_6_30.txt'
# 'article_Machine learning - Wikipedia_2016_1_1.txt'
# 'article_Machine learning - Wikipedia_2016_6_30.txt'
# 'article_Machine learning - Wikipedia_2017_1_1.txt'
# 'article_Machine learning - Wikipedia_2017_6_29.txt'
# 'article_Machine learning - Wikipedia_2018_1_5.txt'
# 'article_Machine learning - Wikipedia_2018_6_29.txt'
# 'article_Machine learning - Wikipedia_2019_1_2.txt'
# 'article_Machine learning - Wikipedia_2019_6_24.txt'
# 'article_Machine learning - Wikipedia_2020_1_8.txt'
# 'article_Machine learning - Wikipedia_2020_6_30.txt'
# 'article_Machine learning - Wikipedia_2021_1_8.txt'
# 'article_Machine learning - Wikipedia_2021_6_19.txt'
# ...

# %%
# %cd /content
# Out:
# /content

# %% [markdown]
# **copying my files to my drive**

# %% [markdown]
# <FONT SIZE=18 COLOR="RED">NOTE</FONT><BR>
# PLACE YOUR OWN LINK TO YOUR DRIECTORY HERE

# %%
# !cp -r wikipedia-ml wikipedia-ml-raw /content/drive/MyDrive/Big_data_assignment_files
